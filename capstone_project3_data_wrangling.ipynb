# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('data\Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# remove rows with null Customer IDs
df = df[df['CustomerID' ].notna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
#convert Costomer ID data type from float to integer
df.loc[:, 'CustomerID'] = df['CustomerID'].astype('int')
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int32
# Country                object
# dtype: object

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom

# %%
df[(df.Quantity==0) | (df.UnitPrice <= 0)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 47068     540372     22090              PAPER BUNTING RETROSPOT        24
# 47070     540372     22553               PLASTERS IN TIN SKULLS        24
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED         2
# 157042    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE         1
# 187613    553000     47566                        PARTY BUNTING         4
# ...

# %%
df.drop(df.index[df.UnitPrice == 0], inplace=True)

# %%
df[(df.Quantity==0) | (df.UnitPrice <= 0)].shape
# Out:
# (0, 8)

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          361854
# Germany                   9493
# France                    8490
# EIRE                      7483
# Spain                     2532
# Netherlands               2367
# Belgium                   2069
# Switzerland               1876
# Portugal                  1480
# Australia                 1256
# Norway                    1085
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# ...

# %%
df[df.Quantity<=0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df.InvoiceNo.str.startswith('C') == 1]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#check whether the invoice numbers always start with 'C' wherever the negative quantities occur
set(df[df.InvoiceNo.str.startswith('C') == 1].index) - set(df[df.Quantity<=0].index)
# Out:
# set()

# %%
set(df[df.Quantity<=0].index) - set(df[df.InvoiceNo.str.startswith('C') == 1].index)
# Out:
# set()

# %% [markdown]
# Conclusion: all the rows with negative quantity have the Invoices start with 'C' which may stand for cancelation

# %%
negative_quantity_df = df[df.Quantity<=0].copy()
negative_quantity_df.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50       14527  United Kingdom
# 154 2010-12-01 09:49:00       4.65       15311  United Kingdom
# 235 2010-12-01 10:24:00       1.65       17548  United Kingdom
# 236 2010-12-01 10:24:00       0.29       17548  United Kingdom
# 237 2010-12-01 10:24:00       0.29       17548  United Kingdom

# %%
negative_quantity_df.tail()
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540449 2011-12-09 09:57:00       0.83       14397  United Kingdom
# 541541 2011-12-09 10:28:00     224.69       15498  United Kingdom
# 541715 2011-12-09 11:57:00      10.95       15311  United Kingdom
# 541716 2011-12-09 11:58:00       1.25       17315  United Kingdom
# 541717 2011-12-09 11:58:00       1.25       17315  United Kingdom

# %%
negative_quantity_df.InvoiceNo.str.len().unique()
# Out:
# array([7], dtype=int64)

# %%
negative_quantity_df['InvoiceNum'] = negative_quantity_df.InvoiceNo.str.slice(1).astype('int')
negative_quantity_df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int32
# Country                object
# InvoiceNum              int32
# dtype: object

# %%
negative_quantity_df.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country  InvoiceNum
# 141 2010-12-01 09:41:00      27.50       14527  United Kingdom      536379
# 154 2010-12-01 09:49:00       4.65       15311  United Kingdom      536383
# 235 2010-12-01 10:24:00       1.65       17548  United Kingdom      536391
# 236 2010-12-01 10:24:00       0.29       17548  United Kingdom      536391
# 237 2010-12-01 10:24:00       0.29       17548  United Kingdom      536391

# %%
positive_quantity_df = df[df.Quantity > 0].copy()
positive_quantity_df.shape, positive_quantity_df.dtypes
# Out:
# ((397884, 8),
#  InvoiceNo              object
#  StockCode              object
#  Description            object
#  Quantity                int64
#  InvoiceDate    datetime64[ns]
#  UnitPrice             float64
#  CustomerID              int32
#  Country                object
#  dtype: object)

# %%
positive_quantity_df['InvoiceNum'] = positive_quantity_df.InvoiceNo.astype('int')
positive_quantity_df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int32
# Country                object
# InvoiceNum              int32
# dtype: object

# %%
df[df['CustomerID']==16321]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 64609     541657     22087            PAPER BUNTING WHITE LACE         6
# 64610     541657    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 64611     541657     21056               DOCTOR'S BAG SOFT TOY         3
# 64612     541657     22960            JAM MAKING SET WITH JARS         6
# 84270     543372     22087            PAPER BUNTING WHITE LACE        18
# 84271     543372     22325              MOBILE VINTAGE HEARTS          3
# 84299    C543375     22325              MOBILE VINTAGE HEARTS         -3
# 84300    C543375     22087            PAPER BUNTING WHITE LACE       -18
# 84301     543376     22325              MOBILE VINTAGE HEARTS          3
# 84302     543376     22087            PAPER BUNTING WHITE LACE        18
# 364984    568687     22090             PAPER BUNTING RETROSPOT        12
# 364985    568687     21198        WHITE HEART CONFETTI IN TUBE        24
# ...

# %% [markdown]
# Observations for orders from the Customer with ID 16321: The cancelations came before or at the same time when the orders were placed.

# %%
df[df['CustomerID']==12668].tail(60)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 134089    547822     22979              PANTRY WASHING UP BRUSH        12
# 134090    547822     22982                  PANTRY PASTRY BRUSH        12
# 134091    547822     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 134092    547822     23078             ICE CREAM PEN LIP GLOSS         24
# 134093    547822     23179           CLOCK MAGNET MUM'S KITCHEN         6
# 134094    547822     20750             RED RETROSPOT MINI CASES         2
# 134095    547822     22962                JAM JAR WITH PINK LID        12
# 134096    547822     22467                    GUMBALL COAT RACK         6
# 134097    547822     22221      CAKE STAND LOVEBIRD 2 TIER PINK         2
# 134098    547822     22215       CAKE STAND WHITE TWO TIER LACE         2
# 134099    547822     37500          TEA TIME TEAPOT IN GIFT BOX        12
# 134100    547822     22123                 PING MICROWAVE APRON        12
# ...

# %% [markdown]
# Observations for orders from the Customer with ID 12668: NO orders were placed before cancelation.

# %%
set(positive_quantity_df['InvoiceNum']).intersection(set(negative_quantity_df['InvoiceNum']))
# Out:
# set()

# %% [markdown]
# Conclusion: No orders were placed before order cancelation. So, we'll remove all the rows with negative quantity.

# %%
positive_quantity_df.drop('InvoiceNo', axis=1, inplace=True)
positive_quantity_df.columns
# Out:
# Index(['StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice',
#        'CustomerID', 'Country', 'InvoiceNum'],
#       dtype='object')

# %%
positive_quantity_df.to_excel('data\online_retail_clean.xlsx')

# %%
uk_online_retail_clean = positive_quantity_df[positive_quantity_df.Country=='United Kingdom']
uk_online_retail_clean.shape
# Out:
# (354321, 8)

# %%
uk_online_retail_clean.to_excel('data\\uk_online_retail_clean.xlsx')
